# %% [markdown]
# <a href="https://colab.research.google.com/github/equipealpha3d/py22_1list03-M20170184552/blob/feedback/PythonList05.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **UNIVERSIDADE FEDERAL DO RIO GRANDE DO NORTE**
#
# **DEPARTAMENTO DE ENGENHARIA MECÂNICA**
#
# *ALGORITMOS E LINGUAGEM DE PROGRAMAÇÃO ORIENTADA A OBJETOS*
#
# *PROF. CARLOS MAGNO*

# %% [markdown]
# **QUINTA LISTA DE EXERCÍCIOS**
#
# 1 - Tendo como entrada de dados os valores das coordenadas x e y. Construa uma função que valide a entrada de dados e retorne o par ordenado [TUPLA].
# Execute a chamada a esta função para executar a coleta dos argumentos da função distancia_entre_pontos que também deverá ser construida.
#
# Tendo como base P(x1,y1) e P(x2,y2) as coordenadas dos pontos e a fórmula que efetua tal cálculo:
# $
# \sqrt{(x2 - x1)^2 + (y2 - y1)^2}
# $

# %%
#IMPORTAR A BIBILIOTECA MATEMÁTICA
import math
ponto = tuple
dist = float

#função para validacao
def valida(a,b,c,d):
    try:
        x1 = float(a)
        y1 = float(b)
        x2 = float(c)
        y2 = float(d)
        if(x1 == x2 and y1 == y2):
         print("Os pontos não podem ser iguais, tente novamente")
         return False
    except:
      print("Algo deu errado")
      return False
    else:
      teste == True
      return  ((x1,y1),(x2,y2))

#FUNÇÃO DO CÁLCULO DA DISTÂNCIA DE DOIS PONTOS
def distanciad(x1,y1,x2,y2):
  dist = math.sqrt((x2 - x1)**2 + (y2 - y1)**2)
  return dist


teste = False
while teste == False:
    x1 = input("Entre com a coordenada x1 do primeiro ponto: ")
    y1 = input("Entre com a coordenada y1 do primeiro ponto: ")
    x2 = input("Entre com a coordenada x2 do primeiro ponto: ")
    y2 = input("Entre com a coordenada y2 do primeiro ponto: ")
    teste =  valida(x1,y1,x2,y2)
    

dist = distanciad(float(x1),float(y1),float(x2),float(y2))

#SAÍDA DOS DADOS
print("A DISTÂNICA ENTRE OS DOIS PONTOS É: ",dist)
# Out:
# Entre com a coordenada x1 do primeiro ponto: 1
# Entre com a coordenada y1 do primeiro ponto: 2
# Entre com a coordenada x2 do primeiro ponto: 1
# Entre com a coordenada y2 do primeiro ponto: 2
# Os pontos não podem ser iguais, tente novamente
# Entre com a coordenada x1 do primeiro ponto: 2
# Entre com a coordenada y1 do primeiro ponto: 2
# Entre com a coordenada x2 do primeiro ponto: 2
# Entre com a coordenada y2 do primeiro ponto: 2
# Os pontos não podem ser iguais, tente novamente
# Entre com a coordenada x1 do primeiro ponto: 1
# Entre com a coordenada y1 do primeiro ponto: 2
# Entre com a coordenada x2 do primeiro ponto: 3
# Entre com a coordenada y2 do primeiro ponto: 4
# A DISTÂNICA ENTRE OS DOIS PONTOS É:  2.8284271247461903

# %% [markdown]
# 2 - Construa uma função que execute a validação de entrada de dados para entrada das notas do aluno. Construa uma função que execute o calculo da média das tres notas do aluno e retorne uma [TUPLA] com os valores da média e do status de aprovação e da maior nota.
# Construa uma função para imprimir o formulário com estas informações.

# %%
import turtle


mediaaritmetrica =float
maiornota = float
situacao = str
dados = tuple
#função para validacao
def valida(a):
  try:
    x=float(a)
  except:
      print("Algo deu errado")
      return False
  else:
      return True
#função pra calcular a média, status de aprovação e maior nota
def calcularmedia(nota1,nota2,nota3):
  mediaaritmetrica = (float(nota1)+float(nota2)+float(nota3))/3 
  notas = [nota1,nota2,nota3]
  maiornota = max(notas)
  if mediaaritmetrica >= 7:
    situacao='APROVADO' 
  else: 
    situacao='REPROVADO'
  
  return (nota1,nota2,nota3,mediaaritmetrica,maiornota,situacao)
  
                   
#função para impressão
def imprimirformulario(dados):
  print(50*'_')
  print("{:<3}{:<3}{:<3}{:<6}{:<6}{:<20} ".format('|N1','|N2','|N3','|MÉDIA','|MAIOR NOTA ','| STATUS DO ALUNO '))
  print(50*'_')
  print(dados)
  print(50*'_')

nota1 = float
nota2 = float
nota3 = float

teste = False
while teste == False:
 nota1=input("digite o valor ")
 teste =  valida(nota1)
teste = False
while teste == False:
 nota2=input("digite o valor ")
 teste =  valida(nota2)
teste = False
while teste == False:
   nota3=input("digite o valor ")
   teste =  valida(nota3)
#chamando a função calcularmedia   
dados = calcularmedia(nota1,nota2,nota3)
print(dados)
imprimirformulario(dados)
# Out:
# digite o valor 6
# digite o valor 9
# digite o valor 6
# ('6', '9', '6', 7.0, '9', 'APROVADO')
# __________________________________________________
# |N1|N2|N3|MÉDIA|MAIOR NOTA | STATUS DO ALUNO
# __________________________________________________
# ('6', '9', '6', 7.0, '9', 'APROVADO')
# __________________________________________________

# %% [markdown]
# 3 - Construa as funções necessárias para o calculo do perímetro e da área das seguintes figuras geométricas. Circulo, Quadrado, Retângulo e Triângulo. Contrua uma biblioteca com estas funções e faça um programa que testa as funções de cáluclo dos perimétros e calculo das áreas das figura geométricas.

# %%
import math
import random as rd
#funções
#perímetro do quadrado
def perimetroquadrado(b):
  return 4*b
#perímetro do triângulo
def perimetrotriangulo(a,b,c):
  return a+b+c
#perímetro do retângulo
def perimetroretangulo(b,h):
  return 2*b+2*h
#perímetro do círculo
def perimetrodocirculo(r):
  return math.pi*2*r
#área do quadrado
def areaquadrado(b):
  return b**2
#área do triângulo
def areatriangulo(a,b,c):
 p =perimetrotriangulo(a,b,c)/2
 return math.sqrt(p*(p-a)*(p-b)*(p-c))
#área do retângulo
def areadoretangulo(b,h):
  return b*h
#área do círculo
def areacirculo(r):
  return math.pi*math.pow(r,2)



print(5*"-"," QUADRADO",5*"-")
#área do quadrado 
b = rd.randrange(1,10)
areadoquadrado = areaquadrado(b)
print("base: ",b,"m área do quadrado ",areadoquadrado,"m²")
#perímetro do quadrado
perimetrodoquadrado = perimetroquadrado(b)
print("o perímetro do quadrado é: ",perimetrodoquadrado,"m")


print(5*"-"," CÍRCULO",5*"-")
#área do círculo
r = rd.randrange(1,10)
area1 = areacirculo(r)
print("Raio ",r, "m área do círculo ",area1,"m²")
#perímetro do círculo
perimetrocirculo = perimetrodocirculo(r)
print("O perímetro do circulo é ",perimetrocirculo,"m")


print(5*"-","RETÂNGULO",5*"-")
#área do retângulo 
b = rd.randrange(1,10)
h = rd.randrange(1,10)
arearetangulo = areadoretangulo(b,h)
print("base: ",b,"m altura:",h,"m área do retangulo ",arearetangulo,"m²")
#perímetro do retângulo
perimetrodoretangulo = perimetroretangulo(b,h)
print("o perímetro do retângulo é: ",perimetrodoretangulo,"m")

print(5*"-","TRIÂNGULO",5*"-")
#perímetro do triângulo
x= rd.randrange(1,10)
y= rd.randrange(1,10)
z= rd.randrange(1,10)
perimetrodotriangulo = perimetrotriangulo(x,y,z)
print("O perímetro do triângulo é ", perimetrodotriangulo,"m" )
#área do triângulo
triangulo = areatriangulo(x,y,z)
print("O área do triângulo é ", triangulo,"m²" )
# Out:
# -----  QUADRADO -----
# base:  1 m área do quadrado  1 m²
# o perímetro do quadrado é:  4 m
# -----  CÍRCULO -----
# Raio  1 m área do círculo  3.141592653589793 m²
# O perímetro do circulo é  6.283185307179586 m
# ----- RETÂNGULO -----
# base:  6 m altura: 8 m área do retangulo  48 m²
# o perímetro do retângulo é:  28 m
# ----- TRIÂNGULO -----
# O perímetro do triângulo é  16 m
# O área do triângulo é  0.0 m²

# %% [markdown]
# 4 - Execute o calculo da quantidade de material ( madeira )  necessário para construir a casa do seu cachorro. Utilize a biblioteca construida no programa anterior. Veja a planta

# %% [markdown]
#  ![casaDog2.png](data:image/png;base64,...)

# %%
from cmath import sqrt
import math
import random as rd
from re import X
#funções
#perímetro do quadrado
def perimetroquadrado(b):
  return 4*b
#perímetro do triângulo
def perimetrotriangulo(a,b,c):
  return a+b+c
#perímetro do retângulo
def perimetroretangulo(b,h):
  return 2*b+2*h
#perímetro do círculo
def perimetrodocirculo(r):
  return math.pi*2*r
#área do quadrado
def areaquadrado(b):
  return b**2
#área do triângulo
def areatriangulo(a,b,c):
 p =perimetrotriangulo(a,b,c)/2
 return math.sqrt(p*(p-a)*(p-b)*(p-c))
#área do retângulo
def areadoretangulo(b,h):
  return b*h
#área do círculo
def areacirculo(r):
  return math.pi*math.pow(r,2)
def pitagoras(h,j):
   return math.sqrt(h**2 + j**2)



print(5*"-"," TELHADO",5*"-")
b = 80
h = 51
areatelhado = 2*areadoretangulo(b,h)
print("área dos dois telhados ",areatelhado,"cm²")

print(5*"-"," LATERAL ",5*"-")
bb = 40
hh = 66
arealateral = 2*areadoretangulo(bb,hh)
print(" área das duas laterais ",arealateral,"cm²")

print(5*"-"," PISO ",5*"-")
bbb = 66
hhh = 58
areapiso = areadoretangulo(bbb,hhh)
print("área do piso ",areapiso,"cm²")

print(5*"-"," TRASEIRA ",5*"-")
#arearetangulo
base = 40
alt = 62
arearetangulonatraseira = areadoretangulo(base,alt)
#TRIANGULO
x= 30
y= 31
z= pitagoras(x,y)#chamando função pitadoras
#área do triângulo
triangulo = 2*areatriangulo(x,y,z)
##print("O área do triângulo é ", triangulo,"m²" )
areatotaltraseira = arearetangulonatraseira + triangulo
print ("Área da traseira ",areatotaltraseira,"cm²")

print(5*"-"," FRENTE ",5*"-")
#retangulo da porta
basep = 30
altp = 30
arearetangulonafrente = areadoretangulo(basep,altp)
#círculo da porta
r = 15
areacirculoporta = areacirculo(r)
porta = arearetangulonafrente + areacirculoporta
areatotalfrente = areatotaltraseira - porta
print("Área da frente ",areatotalfrente,"cm²")
print(88*"-")
areatotal = areatelhado + arealateral + areapiso + arearetangulonatraseira + areatotalfrente
print("Área total de madeira será: ", areatotal,"cm²")
# Out:
# -----  TELHADO -----
# área dos dois telhados  8160 cm²
# -----  LATERAL  -----
#  área das duas laterais  5280 cm²
# -----  PISO  -----
# área do piso  3828 cm²
# -----  TRASEIRA  -----
# Área da traseira  3410.0000000000005 cm²
# -----  FRENTE  -----
# Área da frente  1803.141652942297 cm²
# ----------------------------------------------------------------------------------------
# Área total de madeira será:  21551.141652942297 cm²

# %% [markdown]
# 5 - Execute as questões A e B expostas na figura abaixo. Utilizar a bilbioteca do exercicio 3. Se necessário acrestar outras funções.

# %% [markdown]
# ![casaDog.png](data:image/png;base64,...)

# %%
from cmath import sqrt
import math
import random as rd
from re import X
#funções
#perímetro do quadrado
def perimetroquadrado(b):
  return 4*b
#perímetro do triângulo
def perimetrotriangulo(a,b,c):
  return a+b+c
#perímetro do retângulo
def perimetroretangulo(b,h):
  return 2*b+2*h
#perímetro do círculo
def perimetrodocirculo(r):
  return math.pi*2*r
#área do quadrado
def areaquadrado(b):
  return b**2
#área do triângulo
def areatriangulo(a,b,c):
 p =perimetrotriangulo(a,b,c)/2
 return math.sqrt(p*(p-a)*(p-b)*(p-c))
#área do retângulo
def areadoretangulo(b,h):
  return b*h
#área do círculo
def areacirculo(r):
  return math.pi*math.pow(r,2)
def pitagoras(h,j):
   return math.sqrt(h**2 + j**2)



#print(5*"-"," TELHADO",5*"-")
b = 80
h = 51
areatelhado = 2*areadoretangulo(b,h)
#print("área dos dois telhados ",areatelhado,"cm²")

#print(5*"-"," LATERAL ",5*"-")
bb = 40
hh = 66
arealateral = 2*areadoretangulo(bb,hh)
#print(" área das duas laterais ",arealateral,"cm²")

#print(5*"-"," PISO ",5*"-")
bbb = 66
hhh = 58
areapiso = areadoretangulo(bbb,hhh)
#print("área do piso ",areapiso,"cm²")

#print(5*"-"," TRASEIRA ",5*"-")
#arearetangulo
base = 40
alt = 62
arearetangulonatraseira = areadoretangulo(base,alt)
#TRIANGULO
x= 30
y= 31
z= pitagoras(x,y)#chamando função pitadoras
#área do triângulo
triangulo = 2*areatriangulo(x,y,z)
##print("O área do triângulo é ", triangulo,"m²" )
areatotaltraseira = arearetangulonatraseira + triangulo
#print ("Área da traseira ",areatotaltraseira,"cm²")

#print(5*"-"," FRENTE ",5*"-")
#retangulo da porta
basep = 30
altp = 30
arearetangulonafrente = areadoretangulo(basep,altp)
#círculo da porta
r = 15
areacirculoporta = areacirculo(r)
porta = arearetangulonafrente + areacirculoporta
areatotalfrente = areatotaltraseira - porta
#print("Área da frente ",areatotalfrente,"cm²")
#print(88*"-")
areatotal = areatelhado + arealateral + areapiso + arearetangulonatraseira + areatotalfrente
#print("Área total de madeira será: ", areatotal,"cm²")

#função para transformar de cm2 para m2
def transformarcm2param2(area):
  return area/10000
rendimento = float
preco = float
custolateral = float
def rendimentotinta(areacusto,cor):
  if cor == 'azul':
   litros = 0.2*areacusto
  if cor == 'preto':
   litros = 0.3*areacusto
  if cor == 'verde':
   litros = 0.4*areacusto
  return litros
def precos(cor):
  if cor == 'azul':
   preco = 14.10
  if cor == 'preto':
   preco = 15.10
  if cor == 'verde':
   preco = 12.80
  if cor == 'vedacao':
   preco = 2.00
  return preco
def calccusto(preco, litros):
    custo =  preco*litros
    return custo
#QUESTÃO 5 A 
#custo e quantidade de tinta para pintar as laterais da casa de azul
areacustolateralparam2 = transformarcm2param2(arealateral)
corlateral = 'azul'
precolateral = precos(corlateral)
litroslareral = rendimentotinta(areacustolateralparam2,corlateral)
custolateral = calccusto(precolateral, litroslareral)
print(5*"-"," LATERAL ",5*"-")
print("CUSTO DE TINTA")
print("R$",custolateral)
print("litros necessários para pintura ",litroslareral,"L" )


custotelhado = float

#custo e quantidade de tinta para pintar o telhado da casa de preto
areacustotelhadoparam2 = transformarcm2param2(areatelhado)
cortelhado = 'preto'
precotelhado = precos(cortelhado)
litrostelhado = rendimentotinta(areacustotelhadoparam2,cortelhado)
custotelhado = calccusto(precotelhado, litrostelhado)
print(5*"-"," TELHADO ",5*"-")
print("CUSTO DE TINTA")
print("R$",custotelhado)
print("Litros necessários para pintura ",litrostelhado,"L" )

custopiso = float

#custo e quantidade de tinta para pintar o piso de verde
areacustopisoparam2 = transformarcm2param2(areapiso)
corpiso = 'verde'
precopiso = precos(corpiso)
litrospiso = rendimentotinta(areacustopisoparam2,corpiso)
custopiso = calccusto(precopiso, litrospiso)
print(5*"-"," PISO ",5*"-")
print("CUSTO DE TINTA")
print("R$",custopiso)
print("Litros necessários para pintura ",litrospiso,"L" )

#QUESTÃO 5 B
#MATERIAL DE VEDAÇÃO
litrostotais = float
litrostotais = litroslareral + litrostelhado + litrospiso
print("Litros necessários para pintura de vedação ",litrostotais,"L" )
#considerando R$ 2,00 por cada metro quadrado
areatotaldecusto  = areacustolateralparam2 + areacustotelhadoparam2 + areacustopisoparam2
material = 'vedacao'
precovedacao = precos(material)
custovedacao = calccusto(precovedacao,areatotaldecusto)
print("Custo da vedação será de R$",custovedacao )
custototal = custolateral + custotelhado + custopiso + custovedacao
print(55*"-")
print("Custo da total será de R$",custototal )
# Out:
# -----  LATERAL  -----
# CUSTO DE TINTA
# R$ 1.48896
# litros necessários para pintura  0.10560000000000001 L
# -----  TELHADO  -----
# CUSTO DE TINTA
# R$ 3.6964799999999993
# Litros necessários para pintura  0.24479999999999996 L
# -----  PISO  -----
# CUSTO DE TINTA
# R$ 1.9599360000000001
# Litros necessários para pintura  0.15312 L
# Litros necessários para pintura de vedação  0.50352 L
# Custo da vedação será de R$ 3.4536
# -------------------------------------------------------
# Custo da total será de R$ 10.598976

# %%
'''
# Biblioteca de funções 
 
def welcome(): 
  print("Seja bem vindo...") 
   
def imprime(men): 
  print(men) 
   
def valorPI(): 
  return 3.1456 
   
def soma(a,b): 
  return a + b 
 
def subtrair(a,b): 
  return a - b 
   
def potencia(a,b): 
  return a ** b 
   
def duasvezes(c): 
  return c * 2 
  
def somaQuadrados(a,b): 
  return soma(potencia(a,2) , potencia(b,2))  
   
def quadratica(a,b,c): 
  delta = b ** 2 - 4 * a * c 
  if delta > 0: 
    x1 = - b + potencia(delta,1/2) / 2 * a 
    x2 = - b - potencia(delta,1/2) / 2 * a 
  elif delta == 0: 
    x1 = -b + potencia(delta,1/2) / 2 * a 
    x2 = x1 
  else: 
   #  real     = -b / 2 * a 
   #  complexa = potencia(abs(delta),1/2) / 2 * a 
   x1 = -b / 2 * a + potencia(delta,1/2) / 2 * a 
   x2 = -b / 2 * a - potencia(delta,1/2) / 2 * a 
   # x1 = str(real) + " + " + str(complexa) 
  #  x2 = str(real) + " - " + str(complexa)  
  return x1, x2
Biblioteca
def valida(a,b): 
  try: 
    x = float(a) 
    y = float(b) 
  except: 
    print("Algo deu errado") 
    return False 
  else: 
    return True
coloque junto a biblioteca
O PROGRMA
import mybibi as mb 

''' 
'''
raio = int(input("Digite o raio:")) 
 
area = mb.valorPI() * mb.potencia(raio,2) 
 
mb.imprime("soma dos quadrados : " + str(mb.somaQuadrados(2,4))) 
 
x = input("digite x:") 
y = input("digite y:") 
z = input("digite z:") 
 
( c, d ) =  mb.quadratica(x,y,z) # 1, -6, 9  - 2,8,5  -- 2,1,5 
 
print("Raiz 1 :", c) 
print("Raiz 2 :", d) 
 
print(type(c),type(d)) 
 
 
 
x = True 
while x == True: 
  try: 
    pontos = int(input("entre com o numero de pts.")) 
    if(pontos > 120): 
      pontos = pontos/classe 
    elif pontos < 0: 
      pontos = pontos / 0 
    else: 
      pontos += 1 
  except NameError: 
    print("variavel nao definida") 
  except ZeroDivisionError: 
    print("valores dividdos por zero") 
  except: 
    print("Algo deu errado") 
    x = False 
  else: 
    print("Este é o total de pontos:", pontos) 
  finally: 
    print("estou indo embora") 

 
 
     
   
teste = False     
while teste == False: 
  zz = input("digite o valor 1 ") 
  gg =  input("digite o valor 2") 
  teste = mb.valida(zz,gg) 
   
print(mb.soma(float(zz),float(gg)))
'''
